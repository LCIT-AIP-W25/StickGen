# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls "/content/drive/MyDrive/AIP_Project/week 7 /Datasets/images_preprocessed" | head -10
# Out:
# emoji_0.png
# emoji_1000.png
# emoji_1001.png
# emoji_1002.png
# emoji_1003.png
# emoji_1004.png
# emoji_1005.png
# emoji_1006.png
# emoji_1007.png
# emoji_1008.png

# %%
import json

json_path = "/content/drive/MyDrive/AIP_Project/week 7 /Datasets/preprocessed_text_cleaned (1).json"

# Load and display first 5 entries
with open(json_path, "r") as f:
    dataset = json.load(f)

print(json.dumps(dataset[:5], indent=4))
# Out:
# [
#     {
#         "image": "emoji_0.png",
#         "text": "<|startoftext|>\ud83c\udf0d news update : grinning _ face is making headlines today ! <|endoftext|>"
#     },
#     {
#         "image": "emoji_1.png",
#         "text": "<|startoftext|>\ud83c\udf0d news update : smiling _ face _ with _ open _ mouth is making headlines today ! <|endoftext|>"
#     },
#     {
#         "image": "emoji_2.png",
#         "text": "<|startoftext|>\ud83c\udf0d news update : winking _ face is making headlines today ! <|endoftext|>"
#     },
#     {
#         "image": "emoji_3.png",
#         "text": "<|startoftext|>\ud83c\udfad pop culture : robot _ face is the latest internet sensation ! <|endoftext|>"
#     },
#     {
#         "image": "emoji_4.png",
#         "text": "<|startoftext|>\ud83c\udfad pop culture : father _ christmas is the latest internet sensation ! <|endoftext|>"
#     }
# ]

# %% [markdown]
# # **Checking The datasets**

# %%
import os
import json

# Paths
image_folder = "/content/drive/MyDrive/AIP_Project/week 7 /Datasets/images_preprocessed"
json_path = "/content/drive/MyDrive/AIP_Project/week 7 /Datasets/preprocessed_text_cleaned (1).json"

# Load JSON file
with open(json_path, "r") as f:
    dataset = json.load(f)

# Get total counts
total_images = len(os.listdir(image_folder))
total_text_entries = len(dataset)

# Print dataset status
print(f"Final Dataset Check Passed!")
print(f"Total Images Available: {total_images}")
print(f"Total Text Entries Available: {total_text_entries}")

# Confirm all entries match
if total_images >= total_text_entries:
    print(" Perfect Match! Ready for training!")
else:
    print(" WARNING: Image and text counts do not match. Double-check your dataset.")
# Out:
# Final Dataset Check Passed!
# Total Images Available: 2671
# Total Text Entries Available: 2151
#  Perfect Match! Ready for training!

# %% [markdown]
# # **Install Required Libraries**

# %%
# !pip install diffusers accelerate transformers datasets safetensors torch torchvision peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# ...

# %%
# !pip install bitsandbytes
# !pip install --upgrade transformers diffusers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 90.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.1/342.1 kB 31.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.3.0
#     Uninstalling accelerate-1.3.0:
#       Successfully uninstalled accelerate-1.3.0
# ...

# %%
from huggingface_hub import model_info

model_name = "valhalla/emoji-diffusion"

try:
    info = model_info(model_name)
    print("Model found on Hugging Face:", info)
except Exception as e:
    print("Model not found or inaccessible:", str(e))
# Out:
# Model found on Hugging Face: ModelInfo(id='valhalla/emoji-diffusion', author='valhalla', sha='590d926ba61e02781bfd4935112015d4432f501d', created_at=datetime.datetime(2022, 11, 17, 11, 41, 9, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2023, 5, 16, 9, 29, 9, tzinfo=datetime.timezone.utc), private=False, disabled=False, downloads=190, downloads_all_time=None, gated=False, gguf=None, inference='warm', likes=69, library_name='diffusers', tags=['diffusers', 'stable-diffusion', 'text-to-image', 'en', 'license:bigscience-bloom-rail-1.0', 'autotrain_compatible', 'endpoints_compatible', 'diffusers:StableDiffusionPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data={'base_model': None, 'datasets': None, 'eval_results': None, 'language': ['en'], 'library_name': None, 'license': 'bigscience-bloom-rail-1.0', 'license_name': None, 'license_link': None, 'metrics': None, 'model_name': None, 'pipeline_tag': None, 'tags': ['stable-diffusion', 'text-to-im
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

model_name = "valhalla/emoji-diffusion"  # my model

pipe = StableDiffusionPipeline.from_pretrained(
    model_name,
    torch_dtype=torch.float16,  # I have keep the precision float16
).to("cuda")

print("Model loaded successfully!")
# Out:
# model_index.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/246M [00:00<?, ?B/s]
# tokenizer%2Fmerges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer%2Ftokenizer_config.json:   0%|          | 0.00/796 [00:00<?, ?B/s]
# tokenizer%2Fspecial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# text_encoder%2Fconfig.json:   0%|          | 0.00/580 [00:00<?, ?B/s]
# scheduler%2Fscheduler_config.json:   0%|          | 0.00/331 [00:00<?, ?B/s]
# tokenizer%2Fvocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# (…)ure_extractor%2Fpreprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# unet%2Fconfig.json:   0%|          | 0.00/785 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/167M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # **Load the Model and Enable LoRA for Fine-Tuning**

# %%
from diffusers import StableDiffusionPipeline
from transformers import BitsAndBytesConfig
import torch

# Model Name
model_name = "valhalla/emoji-diffusion"

# 4-bit Quantization Configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,  # Load model in 4-bit
    bnb_4bit_compute_dtype=torch.float16,  # Compute dtype
    bnb_4bit_quant_type="nf4"  # Quantization type
)

# Load Model with Quantization
pipe = StableDiffusionPipeline.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    quantization_config=bnb_config  # Apply 4-bit quantization
).to("cuda")

print("✅ Model Loaded with 4-bit Quantization!")
# Out:
# Keyword arguments {'quantization_config': BitsAndBytesConfig {
#   "_load_in_4bit": true,
#   "_load_in_8bit": false,
#   "bnb_4bit_compute_dtype": "float16",
#   "bnb_4bit_quant_storage": "uint8",
#   "bnb_4bit_quant_type": "nf4",
#   "bnb_4bit_use_double_quant": false,
#   "llm_int8_enable_fp32_cpu_offload": false,
#   "llm_int8_has_fp16_weight": false,
#   "llm_int8_skip_modules": null,
#   "llm_int8_threshold": 6.0,
#   "load_in_4bit": true,
#   "load_in_8bit": false,
#   "quant_method": "bitsandbytes"
# }
# } are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # **Define LoRA for Correct Modules**

# %%
from peft import LoraConfig, get_peft_model
import torch

# Define LoRA Configuration
lora_config = LoraConfig(
    r=8,  # LoRA rank
    lora_alpha=32,  # Scaling factor
    target_modules=["q_proj", "k_proj", "v_proj", "out_proj"],  # Correct target layers for CLIP
    lora_dropout=0.1,
    bias="none"
)

# Apply LoRA to CLIP Text Encoder
pipe.text_encoder = get_peft_model(pipe.text_encoder, lora_config)

# Apply LoRA to U-Net attention layers
unet_lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["attn1.to_q", "attn1.to_k", "attn1.to_v", "attn2.to_out.0"],  # Correct U-Net attention layers
    lora_dropout=0.1,
    bias="none"
)
pipe.unet = get_peft_model(pipe.unet, unet_lora_config)

print("✅ LoRA Enabled for Fine-Tuning on U-Net and CLIP!")
# Out:
# ✅ LoRA Enabled for Fine-Tuning on U-Net and CLIP!

# %% [markdown]
# # **Verify LoRA is Applied**

# %%
def count_trainable_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Trainable Parameters in U-Net:", count_trainable_params(pipe.unet))
print("Trainable Parameters in Text Encoder:", count_trainable_params(pipe.text_encoder))
# Out:
# Trainable Parameters in U-Net: 798720
# Trainable Parameters in Text Encoder: 589824

# %%
pipe.to("cuda")
pipe.unet.to("cuda")
pipe.text_encoder.to("cuda")
# Out:
# PeftModel(
#   (base_model): LoraModel(
#     (model): CLIPTextModel(
#       (text_model): CLIPTextTransformer(
#         (embeddings): CLIPTextEmbeddings(
#           (token_embedding): Embedding(49408, 768)
#           (position_embedding): Embedding(77, 768)
#         )
#         (encoder): CLIPEncoder(
#           (layers): ModuleList(
#             (0-11): 12 x CLIPEncoderLayer(
#               (self_attn): CLIPSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
# ...

# %% [markdown]
# # **Load and Preprocess Dataset**

# %%
from torch.utils.data import Dataset, DataLoader
import os
import json
from PIL import Image
from torchvision import transforms
from transformers import CLIPTextModel, CLIPTokenizer
from diffusers import AutoencoderKL

# Paths to dataset
image_folder = "/content/drive/MyDrive/AIP_Project/week 7 /Datasets/images_preprocessed"  # image dataset folder
json_path = "/content/drive/MyDrive/AIP_Project/week 7 /Datasets/preprocessed_text_cleaned (1).json"  # JSON file dataset

# Load JSON dataset
with open(json_path, "r") as f:
    dataset = json.load(f)

# Define custom dataset class
class EmojiDataset(Dataset):
    def __init__(self, dataset, image_folder, tokenizer, text_encoder, vae, max_seq_length=50):
        self.dataset = dataset
        self.image_folder = image_folder
        self.tokenizer = tokenizer
        self.text_encoder = text_encoder
        self.vae = vae
        self.max_seq_length = max_seq_length
        self.image_transform = transforms.Compose([
            transforms.Resize((128, 128)),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])
        ])

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        text = self.dataset[idx]["text"]
        tokens = self.tokenizer(text, padding="max_length", truncation=True, max_length=self.max_seq_length, return_tensors="pt").to("cuda")

        with torch.no_grad():
            text_embeddings = self.text_encoder(tokens.input_ids).last_hidden_state

        image_path = os.path.join(self.image_folder, self.dataset[idx]["image"])
        image = Image.open(image_path).convert("RGB")
        image_tensor = self.image_transform(image).unsqueeze(0).to("cuda")

        with torch.no_grad():
            latents = self.vae.encode(image_tensor).latent_dist.sample().squeeze(0) * 0.18215
            latents = latents.cpu()

        timestep = torch.randint(0, 1000, (1,))

        return {
            "sample": latents,
            "timestep": timestep,
            "encoder_hidden_states": text_embeddings.squeeze(0).cpu()
        }

# Load tokenizer, text encoder, and VAE
tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")
text_encoder = CLIPTextModel.from_pretrained("openai/clip-vit-large-patch14").to("cuda")
vae = AutoencoderKL.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="vae").to("cuda")

# Create dataset
emoji_dataset = EmojiDataset(dataset, image_folder, tokenizer, text_encoder, vae)

# Define DataLoader
train_dataloader = DataLoader(emoji_dataset, batch_size=4, shuffle=True, pin_memory=False)

print(f"✅ DataLoader Created! Total Batches: {len(train_dataloader)}")
# Out:
# ✅ DataLoader Created! Total Batches: 538

# %% [markdown]
# # **Define Training Loop**

# %%
import torch.nn.functional as F
from tqdm import tqdm

# Enable training mode
pipe.unet.train().to("cuda")

# Define optimizer
optimizer = torch.optim.AdamW(pipe.unet.parameters(), lr=2e-6)

num_epochs = 50
print("Starting Fine-Tuning...")

for epoch in range(num_epochs):
    total_loss = 0
    progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch in progress_bar:
        optimizer.zero_grad()

        latents = batch["sample"].to("cuda").to(torch.float16)
        timesteps = batch["timestep"].squeeze(-1).to("cuda")
        encoder_hidden_states = batch["encoder_hidden_states"].to("cuda").to(torch.float16)

        noise = torch.randn_like(latents, dtype=torch.float16)
        noisy_latents = latents + noise * 0.1
        predicted_noise = pipe.unet(noisy_latents, timesteps, encoder_hidden_states).sample

        loss = F.mse_loss(predicted_noise, noise)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        progress_bar.set_postfix({"Loss": loss.item()})

    print(f" Epoch {epoch+1} Complete! Average Loss: {total_loss / len(train_dataloader):.4f}")

print("Fine-Tuning Complete!")
# Out:
# Starting Fine-Tuning...
# Epoch 1/50: 100%|██████████| 538/538 [16:29<00:00,  1.84s/it, Loss=1.17]
#  Epoch 1 Complete! Average Loss: 0.9820
# Epoch 2/50: 100%|██████████| 538/538 [02:14<00:00,  4.01it/s, Loss=0.783]
#  Epoch 2 Complete! Average Loss: 0.9484
# Epoch 3/50: 100%|██████████| 538/538 [02:13<00:00,  4.04it/s, Loss=0.868]
#  Epoch 3 Complete! Average Loss: 0.9201
# Epoch 4/50: 100%|██████████| 538/538 [02:13<00:00,  4.03it/s, Loss=0.874]
#  Epoch 4 Complete! Average Loss: 0.8858
# Epoch 5/50: 100%|██████████| 538/538 [02:13<00:00,  4.03it/s, Loss=0.819]
#  Epoch 5 Complete! Average Loss: 0.8591
# Epoch 6/50: 100%|██████████| 538/538 [02:13<00:00,  4.02it/s, Loss=0.813]
#  Epoch 6 Complete! Average Loss: 0.8434
# Epoch 7/50: 100%|██████████| 538/538 [02:12<00:00,  4.06it/s, Loss=0.841]
#  Epoch 7 Complete! Average Loss: 0.8226
# Epoch 8/50: 100%|██████████| 538/538 [02:12<00:00,  4.07it/s, Loss=0.854]
#  Epoch 8 Complete! Average Loss: 0.8061
# ...

# %%
from diffusers import StableDiffusionPipeline

# Define save path
save_path = "/content/drive/MyDrive/AIP_Project/week 7 /50_epoch_save"

# Save all model components
pipe.save_pretrained(save_path)
pipe.unet.save_pretrained(f"{save_path}/unet")
pipe.text_encoder.save_pretrained(f"{save_path}/text_encoder")
pipe.tokenizer.save_pretrained(f"{save_path}/tokenizer")
pipe.vae.save_pretrained(f"{save_path}/vae")
pipe.scheduler.save_pretrained(f"{save_path}/scheduler")

print(f"✅ Fine-Tuned Model Successfully Saved at: {save_path}")
# Out:
# self.text_encoder=PeftModel(
#   (base_model): LoraModel(
#     (model): CLIPTextModel(
#       (text_model): CLIPTextTransformer(
#         (embeddings): CLIPTextEmbeddings(
#           (token_embedding): Embedding(49408, 768)
#           (position_embedding): Embedding(77, 768)
#         )
#         (encoder): CLIPEncoder(
#           (layers): ModuleList(
#             (0-11): 12 x CLIPEncoderLayer(
#               (self_attn): CLIPSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
# ...

# %%
import os

print("Checking saved components:")
print("UNet:", os.listdir(f"{save_path}/unet") if os.path.exists(f"{save_path}/unet") else "❌ MISSING")
print("Text Encoder:", os.listdir(f"{save_path}/text_encoder") if os.path.exists(f"{save_path}/text_encoder") else "❌ MISSING")
print("Tokenizer:", os.listdir(f"{save_path}/tokenizer"))
print("VAE:", os.listdir(f"{save_path}/vae"))
print("Scheduler:", os.listdir(f"{save_path}/scheduler"))
# Out:
# Checking saved components:
# UNet: ['README.md', 'adapter_model.safetensors', 'adapter_config.json']
# Text Encoder: ['README.md', 'adapter_model.safetensors', 'adapter_config.json']
# Tokenizer: ['tokenizer_config.json', 'special_tokens_map.json', 'vocab.json', 'merges.txt']
# VAE: ['config.json', 'diffusion_pytorch_model.safetensors']
# Scheduler: ['scheduler_config.json']
